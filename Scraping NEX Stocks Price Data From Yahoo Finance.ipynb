# %% [markdown]
# ## Importing libraries

# %%
import yfinance as yf

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import json
import datetime as dt

# %% [markdown]
# ## Loading the dataframe with the subset of the NEX index

# %%
df = pd.read_csv('./Finance_Data/NEX_stocks.csv', index_col=0)

symbols = df['symbol'].values

df = yf.download(" ".join(symbols), interval='1d', groupby='ticker')['Close']
df = np.round(df, 2)
# Out:
# [*********************100%***********************]  37 of 37 completed

# %% [markdown]
# ## Selecting only timeframe of the original NEX index

# %%
df = df.loc['2006-03-06':'2019-12-31']

# %%
# Remove dates without any price information
df = df[df.sum(axis=1) != 0]

# %% [markdown]
# ## Weighting companies

# %%
N = symbols.size
weights = []
for i, _ in df.iterrows():
    w = df.loc[i][df.loc[i] > 0].size / N
    weights.append(w)
    
df['weight'] = weights

# %% [markdown]
# ## Computing 90 day Exponential Moving Average

# %%
S = df.sum(axis=1)
S *= df['weight']
S = S.ewm(span=90, adjust=False).mean()

# %% [markdown]
# ## Visualizing 90 day EMA

# %%
plt.figure(figsize=(25, 8))
sns.lineplot(x=df.index, y=S)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Loading and visualizing the full NEX index

# %%
nx = pd.read_excel('./Finance_Data/NEX_close_data.xlsx', header=1)
nx['Close'] = nx['Close'].ewm(span=30, adjust=False).mean()
plt.figure(figsize=(25, 8))
sns.lineplot(x='Date', y='Close', data=nx)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Close'>
